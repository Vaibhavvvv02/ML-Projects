# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaibhavvvv02/ML-Projects/blob/main/Non-LinearTransformation%20using%20ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
x = np.array([1, 2, 3, 4])
y = x**2 + np.sin(x)

# %%
print("Transformed:", y)
# Out:
# Transformed: [ 1.84147098  4.90929743  9.14112001 15.2431975 ]
