# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaibhavvvv02/ML-Projects/blob/main/linearTransformation%20using%20ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
x = np.array([2, 3])
W = np.array([[1, 2],
              [3, 4]])

# %%
b = np.array([1, 1])

# %%
y = np.dot(W, x) + b

print("Output:", y)
# Out:
# Output: [ 9 19]
